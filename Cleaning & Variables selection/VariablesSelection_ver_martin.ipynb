# %%
from __future__ import annotations

import pandas as pd
from pandas.api.types import is_numeric_dtype

import numpy as np

# %% [markdown]
# ## 0 - Preparation
# ### 0.0 - Data import

# %%
DATA_FILE = "data/cleaned data.xlsx"
DESCR_FILE = "data/Table_fields_merged.xlsx"

# %%
df_raw = pd.read_excel(DATA_FILE, sheet_name=1)
df_raw.head()
# Out:
#         name  essround  edition    proddate  idno cntry  nwspol  netusoft  \
# 0  ESS9e03_1         9      3.1  17.02.2021     3    IT      60         4
# 1  ESS9e03_1         9      3.1  17.02.2021    13    IT    8888         5
# 2  ESS9e03_1         9      3.1  17.02.2021    31    IT      30         5
# 3  ESS9e03_1         9      3.1  17.02.2021    58    IT     900         5
# 4  ESS9e03_1         9      3.1  17.02.2021   122    IT      60         5
#
#    netustm  ppltrst  ...  uempla  uempli  dsbld  rtrd  cmsrv  hswrk   dweight  \
# 0      120        2  ...       0       1      0     0      0      0  1.019588
# 1      240        5  ...       0       1      0     0      0      0  1.038898
# 2      180        4  ...       0       0      0     0      0      0  1.050053
# 3      180        6  ...       0       0      0     0      0      0  0.872215
# 4       15        2  ...       0       0      0     0      0      0  1.019588
#
#     pspwght   pweight  anweight
# 0  0.924885  1.909064  1.765664
# 1  0.954811  1.909064  1.822796
# 2  0.816516  1.909064  1.558781
# 3  0.986662  1.909064  1.883601
# 4  1.436108  1.909064  2.741621
#
# [5 rows x 184 columns]

# %%
df_raw.describe()
# Out:
#        essround       edition          idno       nwspol     netusoft  \
# count    2745.0  2.745000e+03   2745.000000  2745.000000  2745.000000
# mean        9.0  3.100000e+00  34868.096903   459.951184     3.635337
# std         0.0  4.441701e-16  20391.645391  1569.666239     1.650821
# min         9.0  3.100000e+00      3.000000     0.000000     1.000000
# 25%         9.0  3.100000e+00  17495.000000    30.000000     2.000000
# 50%         9.0  3.100000e+00  34654.000000    60.000000     5.000000
# 75%         9.0  3.100000e+00  52624.000000   150.000000     5.000000
# max         9.0  3.100000e+00  69961.000000  8888.000000     8.000000
#
#            netustm      ppltrst      pplfair       pplhlp      polintr  ...  \
# count  2745.000000  2745.000000  2745.000000  2745.000000  2745.000000  ...
# mean   2735.492168     5.050638     5.575956     4.688889     2.973406  ...
# std    3249.315166     5.199096     8.129967     5.906410     0.916137  ...
# min       0.000000     0.000000     0.000000     0.000000     1.000000  ...
# 25%     120.000000     3.000000     3.000000     3.000000     2.000000  ...
# 50%     240.000000     5.000000     5.000000     4.000000     3.000000  ...
# 75%    6666.000000     7.000000     6.000000     6.000000     4.000000  ...
# max    8888.000000    88.000000    88.000000    88.000000     8.000000  ...
#
#             uempla       uempli        dsbld         rtrd   cmsrv  \
# count  2745.000000  2745.000000  2745.000000  2745.000000  2745.0
# mean      0.075774     0.029872     0.007286     0.256102     0.0
# std       0.264685     0.170267     0.085062     0.436558     0.0
# min       0.000000     0.000000     0.000000     0.000000     0.0
# 25%       0.000000     0.000000     0.000000     0.000000     0.0
# 50%       0.000000     0.000000     0.000000     0.000000     0.0
# 75%       0.000000     0.000000     0.000000     1.000000     0.0
# max       1.000000     1.000000     1.000000     1.000000     0.0
#
#              hswrk      dweight      pspwght      pweight     anweight
# count  2745.000000  2745.000000  2745.000000  2745.000000  2745.000000
# mean      0.103825     1.000033     1.000000     1.909064     1.909064
# std       0.305089     0.066344     0.175315     0.000000     0.334687
# min       0.000000     0.581986     0.455010     1.909064     0.868642
# 25%       0.000000     0.972131     0.891878     1.909064     1.702651
# 50%       0.000000     1.010092     0.983470     1.909064     1.877508
# 75%       0.000000     1.038898     1.096375     1.909064     2.093050
# max       1.000000     1.096735     1.678103     1.909064     3.203605
#
# [8 rows x 175 columns]

# %%
# Create a copy of original data to be modified
df = df_raw.copy()

# %%
df_descr = pd.read_excel(DESCR_FILE)
df_descr.set_index("Name", drop=True, append=False, inplace=True)
df_descr.head()
# Out:
#                                                       Label        Type  \
# Name
# cntry                                               Country    discrete
# dweight                                       Design weight  continuous
# pspwght   Post-stratification weight including design we...  continuous
# pweight   Population size weight (must be combined with ...  continuous
# anweight                                    Analysis weight  continuous
#
#                Format    Valid  Invalid  \
# Name
# cntry     character-2  49519.0      0.0
# dweight   numeric-4.2  49519.0      0.0
# pspwght   numeric-4.2  49519.0      0.0
# pweight   numeric-8.2  49519.0      0.0
# anweight  numeric-4.2  49519.0      0.0
#
#                                                    Question
# Name
# cntry                                             5 Country
# dweight                                   R17 Design weight
# pspwght   R18 Post-stratification weight including desig...
# pweight   R19 Population size weight (must be combined w...
# anweight                                    Analysis weight

# %% [markdown]
# ### 0.1 Create helper function to get summary of columns

# %%
def get_summary_table(df: pd.DataFrame,
                      target_col: str,
                      corr_method: str="pearson",
                      descr_df: pd.DataFrame=None,
                      descr_cols: list[str]=["Label", "Type"]) -> pd.DataFrame:
    """Return a pandas dataframe where each row corresponds to a column of df
    and each column contains some properties of that column from df.

    Parameters
    ----------
    df : pd.DataFrame
        The pandas dataframe of shape (N, K) containing the data.
    target_col : str
        The label of the column that contains the variable of interest which
        will be studied as the dependent variable. 
    corr_method : {‘pearson’, ‘kendall’, ‘spearman’} or callable
        Method to be used to compute the correlation with target col. By default
        is 'pearson'.
    descr_df : pd.DataFrame, optional
        If dataframe is passed, it will be merged on summary table. The passed
        dataframe should have the variables codes as index. If None, nothing
        happens. By default is None.
    descr_cols : list[str], optional
        List of columns labels to be imported from descr_df. By default is
        'Label' and 'Type'.

    Returns
    -------
    pd.DataFrame
        Dataframe of shape (K, 9).
    """
    df_summary = pd.DataFrame({
    "IS_NUMERIC": df.apply(lambda x: int(is_numeric_dtype(x))),
    "N_UNIQUE" : df.apply(lambda x: x.nunique()),
    "NA_ABS" : df.apply(lambda x: x.isna().sum()),    ## count of NAs in that column
    "NA_REL": df.apply(lambda x: x.isna().mean()),
    "MIN": df.apply(lambda x: x.min() if is_numeric_dtype(x) else np.nan),
    "MAX": df.apply(lambda x: x.max() if is_numeric_dtype(x) else np.nan),
    "MEAN": df.apply(lambda x: x.mean() if is_numeric_dtype(x) else np.nan),
    "MEDIAN": df.apply(lambda x: x.median() if is_numeric_dtype(x) else np.nan),
    "CORR_TARGET": df.apply(lambda x: x.corr(df[target_col], method=corr_method) if is_numeric_dtype(x) else np.nan),
    "SHARE_MOST_FREQ": df.apply(lambda x: x.value_counts(normalize=True).max()),
    }).round(2)
    
    if descr_df is None:
        return df_summary
    
    df_summary = pd.merge(
        df_summary,
        df_descr[descr_cols],
        how="left",
        left_index=True,
        right_index=True
    )
    df_summary.columns = df_summary.columns.str.upper()
    return df_summary

# %%
df_summary = get_summary_table(df, target_col="happy")
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL   MIN       MAX      MEAN  \
# name               0         1       0     0.0   NaN       NaN       NaN
# essround           1         1       0     0.0  9.00      9.00      9.00
# edition            1         1       0     0.0  3.10      3.10      3.10
# proddate           0         1       0     0.0   NaN       NaN       NaN
# idno               1      2745       0     0.0  3.00  69961.00  34868.10
# ...              ...       ...     ...     ...   ...       ...       ...
# hswrk              1         2       0     0.0  0.00      1.00      0.10
# dweight            1        29       0     0.0  0.58      1.10      1.00
# pspwght            1       445       0     0.0  0.46      1.68      1.00
# pweight            1         1       0     0.0  1.91      1.91      1.91
# anweight           1       445       0     0.0  0.87      3.20      1.91
#
#             MEDIAN  CORR_TARGET  SHARE_MOST_FREQ
# name           NaN          NaN             1.00
# essround      9.00          NaN             1.00
# edition       3.10         0.00             1.00
# proddate       NaN          NaN             1.00
# idno      34654.00         0.01             0.00
# ...            ...          ...              ...
# hswrk         0.00         0.01             0.90
# dweight       1.01        -0.01             0.10
# pspwght       0.98        -0.00             0.02
# pweight       1.91          NaN             1.00
# anweight      1.88        -0.00             0.02
#
# [184 rows x 10 columns]

# %% [markdown]
# ## 1 - Variables selection

# %% [markdown]
# ### 1.1 - Drop variables with a single value
# We first drop the columns attaining a single value, as they provide no information at all.

# %%
unique_val_cols = df_summary[df_summary["N_UNIQUE"] == 1].index
unique_val_cols
# Out:
# Index(['name', 'essround', 'edition', 'proddate', 'cntry', 'dscrna', 'cmsrv',
#        'pweight'],
#       dtype='object')

# %%
df.drop(columns=unique_val_cols, inplace=True)

# %% [markdown]
# We can update the summary df, we see that we have now 176 variables.

# %%
df_summary = get_summary_table(df, target_col="happy")
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL   MIN       MAX      MEAN  \
# idno               1      2745       0     0.0  3.00  69961.00  34868.10
# nwspol             1       297       0     0.0  0.00   8888.00    459.95
# netusoft           1         7       0     0.0  1.00      8.00      3.64
# netustm            1        63       0     0.0  0.00   8888.00   2735.49
# ppltrst            1        13       0     0.0  0.00     88.00      5.05
# ...              ...       ...     ...     ...   ...       ...       ...
# rtrd               1         2       0     0.0  0.00      1.00      0.26
# hswrk              1         2       0     0.0  0.00      1.00      0.10
# dweight            1        29       0     0.0  0.58      1.10      1.00
# pspwght            1       445       0     0.0  0.46      1.68      1.00
# anweight           1       445       0     0.0  0.87      3.20      1.91
#
#             MEDIAN  CORR_TARGET  SHARE_MOST_FREQ
# idno      34654.00         0.01             0.00
# nwspol       60.00         0.03             0.21
# netusoft      5.00         0.07             0.50
# netustm     240.00        -0.04             0.36
# ppltrst       5.00         0.18             0.18
# ...            ...          ...              ...
# rtrd          0.00        -0.07             0.74
# hswrk         0.00         0.01             0.90
# dweight       1.01        -0.01             0.10
# pspwght       0.98        -0.00             0.02
# anweight      1.88        -0.00             0.02
#
# [176 rows x 10 columns]

# %% [markdown]
# ### 1.2 - Drop variables concerning the conduction of the study
# There are a few columns merely related to the conduction of the study, we can drop them.

# %%
df.drop(columns=["idno", "dweight", "pspwght", "anweight"], inplace=True)

# %% [markdown]
# There are now 172 variables in the dataset.

# %%
df_summary = get_summary_table(df, target_col="happy")
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN     MAX     MEAN  MEDIAN  \
# nwspol             1       297       0     0.0  0.0  8888.0   459.95    60.0
# netusoft           1         7       0     0.0  1.0     8.0     3.64     5.0
# netustm            1        63       0     0.0  0.0  8888.0  2735.49   240.0
# ppltrst            1        13       0     0.0  0.0    88.0     5.05     5.0
# pplfair            1        13       0     0.0  0.0    88.0     5.58     5.0
# ...              ...       ...     ...     ...  ...     ...      ...     ...
# uempla             1         2       0     0.0  0.0     1.0     0.08     0.0
# uempli             1         2       0     0.0  0.0     1.0     0.03     0.0
# dsbld              1         2       0     0.0  0.0     1.0     0.01     0.0
# rtrd               1         2       0     0.0  0.0     1.0     0.26     0.0
# hswrk              1         2       0     0.0  0.0     1.0     0.10     0.0
#
#           CORR_TARGET  SHARE_MOST_FREQ
# nwspol           0.03             0.21
# netusoft         0.07             0.50
# netustm         -0.04             0.36
# ppltrst          0.18             0.18
# pplfair          0.17             0.19
# ...               ...              ...
# uempla          -0.05             0.92
# uempli           0.01             0.97
# dsbld           -0.01             0.99
# rtrd            -0.07             0.74
# hswrk            0.01             0.90
#
# [172 rows x 10 columns]

# %% [markdown]
# ### 1.3 - Missing values encoding
# Missing values are not encoded as such in the dataset, but are instead replaced
# by numeric values out of the ordinary scale. For the correctness of the study,
# these should be properly substituted by nan.

# %% [markdown]
# #### 1.3.1 - Nan based on maximum values
# The study encodes answers in a numeric scale, using high, out of scale values, to encode missing, refusals or invalid answers.
#
# In this way, by looking at the maximum value for the column, we can infer which
# are the missing values used. In particular:
# - If MAX in [6666, 7777, 8888, 9999] then these will be the values to be mapped to nan
# - If MAX in [666, 777, 888, 999] then these will be the values to be mapped to nan
# - If MAX in [66, 77, 88, 99] then these will be the values to be mapped to nan
# - If MAX in [6, 7, 8, 9] then these will be the values to be mapped to nan
#
# While this method might lead to some mistake, it provides a fast way to start playing around with the data. The nan will be validated again for the final chosen variables.

# %%
df_summary["MAX"].value_counts().sort_index(ascending=False)
# Out:
# 9999.0     4
# 8888.0    13
# 6666.0     3
# 999.0      1
# 888.0     15
# 99.0       3
# 88.0      36
# 77.0       4
# 66.0       4
# 10.0       1
# 9.0        2
# 8.0       47
# 7.0        3
# 6.0        7
# 3.0        1
# 2.0        2
# 1.0       20
# Name: MAX, dtype: int64

# %% [markdown]
# We apply the replacement:

# %%
na_batches = [
    (6666, 7777, 8888, 9999),
    (666, 777, 888, 999),
    (66, 77, 88, 99),
    (6, 7, 8, 9),
]

for col in df_summary[df_summary["IS_NUMERIC"] == 1].index:
    for batch in na_batches:
        if df[col].max() in batch:
            df[col] = df[col].apply(lambda x: np.nan if x in batch else x)
            break

# %%
df_summary = get_summary_table(df, target_col="happy")
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN     MAX    MEAN  MEDIAN  \
# nwspol             1       295      91    0.03  0.0  1233.0  173.90    60.0
# netusoft           1         5       5    0.00  1.0     5.0    3.63     5.0
# netustm            1        60    1064    0.39  0.0   900.0  165.04   120.0
# ppltrst            1        11       9    0.00  0.0    10.0    4.79     5.0
# pplfair            1        11      25    0.01  0.0    10.0    4.83     5.0
# ...              ...       ...     ...     ...  ...     ...     ...     ...
# uempla             1         2       0    0.00  0.0     1.0    0.08     0.0
# uempli             1         2       0    0.00  0.0     1.0    0.03     0.0
# dsbld              1         2       0    0.00  0.0     1.0    0.01     0.0
# rtrd               1         2       0    0.00  0.0     1.0    0.26     0.0
# hswrk              1         2       0    0.00  0.0     1.0    0.10     0.0
#
#           CORR_TARGET  SHARE_MOST_FREQ
# nwspol           0.04             0.22
# netusoft         0.26             0.51
# netustm          0.01             0.17
# ppltrst          0.19             0.18
# pplfair          0.20             0.20
# ...               ...              ...
# uempla          -0.10             0.92
# uempli          -0.02             0.97
# dsbld           -0.02             0.99
# rtrd            -0.16             0.74
# hswrk           -0.00             0.90
#
# [172 rows x 10 columns]

# %% [markdown]
# #### 1.3.2 - Non numeric variables
# For non numeric variables missing values are still encoded as 777, 888, 6666, 7777, 8888 or 9999.

# %%
filt = df_summary["IS_NUMERIC"]==0
non_numeric_cols = df_summary[filt].index
df_summary[filt]
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN  MAX  MEAN  MEDIAN  \
# ctzshipd           0        22       0     0.0  NaN  NaN   NaN     NaN
# cntbrthd           0        27       0     0.0  NaN  NaN   NaN     NaN
# lnghom1            0        23       0     0.0  NaN  NaN   NaN     NaN
# lnghom2            0        20       0     0.0  NaN  NaN   NaN     NaN
# fbrncntc           0        28       0     0.0  NaN  NaN   NaN     NaN
# mbrncntc           0        28       0     0.0  NaN  NaN   NaN     NaN
#
#           CORR_TARGET  SHARE_MOST_FREQ
# ctzshipd          NaN             0.94
# cntbrthd          NaN             0.90
# lnghom1           NaN             0.87
# lnghom2           NaN             0.80
# fbrncntc          NaN             0.90
# mbrncntc          NaN             0.90

# %%
na_vals = [777, 888, 6666, 7777, 8888, 9999]
for col in non_numeric_cols:
    df[col] = df[col].apply(lambda x: np.nan if x in na_vals else x)

# %%
df_summary = get_summary_table(df, target_col="happy")

# %% [markdown]
# #### 1.3.3 - Other special cases
# For the variables "edulvlb" and "edlveit", 'Other' is mapped as 5555. This throws off the scale. We decide to replace it with np.nan as we are not really able to evaluate it.

# %%
for col in ["edulvlb", "edlveit"]:
    df[col] = df[col].replace(5555, np.nan)

# %% [markdown]
# ### 1.4 - Drop variables with too many missing values
# We drop the columns with at least 40% missing values.

# %%
summary_filt = df_summary[df_summary["NA_REL"] >= 0.4]
too_many_nan_cols = summary_filt.index
summary_filt
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL     MIN     MAX     MEAN  \
# prtvtcit           1        14    1463    0.53     1.0    14.0     6.27
# prtcldit           1        13    1691    0.62     1.0    14.0     6.54
# prtdgcl            1         4    1699    0.62     1.0     4.0     2.00
# rlgblge            1         2    2177    0.79     1.0     2.0     1.76
# rlgdnme            1         4    2612    0.95     1.0     7.0     1.11
# ctzshipd           0        19    2612    0.95     NaN     NaN      NaN
# cntbrthd           0        24    2531    0.92     NaN     NaN      NaN
# livecnta           1        50    2511    0.91  1940.0  2018.0  1998.74
# fbrncntc           0        25    2513    0.92     NaN     NaN      NaN
# mbrncntc           0        25    2514    0.92     NaN     NaN      NaN
# nbthcld            1         8    1089    0.40     1.0     8.0     1.89
# fcldbrn            1        74    1143    0.42  1945.0  2019.0  1987.62
# ycldbyr            1        67    1703    0.62  1947.0  2019.0  1989.77
# ngchld             1        17    1512    0.55     0.0    24.0     1.50
# ygcdbyr            1        48    2222    0.81  1968.0  2019.0  2002.17
# ggchld             1         2    2413    0.88     1.0     2.0     1.84
# gndr3              1         2    1358    0.49     1.0     2.0     1.59
# gndr4              1         2    1994    0.73     1.0     2.0     1.45
# gndr5              1         2    2554    0.93     1.0     2.0     1.49
# gndr6              1         2    2695    0.98     1.0     2.0     1.46
# gndr7              1         2    2733    1.00     1.0     2.0     1.33
# gndr8              1         2    2741    1.00     1.0     2.0     1.75
# yrbrn3             1        87    1403    0.51  1928.0  2019.0  1986.54
# yrbrn4             1        62    2025    0.74  1929.0  2018.0  1998.99
# yrbrn5             1        43    2562    0.93  1940.0  2018.0  2000.29
# yrbrn6             1        28    2695    0.98  1935.0  2018.0  2001.38
# yrbrn7             1        10    2733    1.00  1942.0  2018.0  1999.42
# yrbrn8             1         4    2741    1.00  2004.0  2015.0  2008.50
# rshipa3            1         6    1361    0.50     1.0     6.0     2.48
# rshipa4            1         6    1999    0.73     1.0     6.0     2.87
# rshipa5            1         6    2554    0.93     1.0     6.0     3.12
# rshipa6            1         5    2695    0.98     2.0     6.0     3.46
# rshipa7            1         3    2733    1.00     2.0     4.0     3.25
# rshipa8            1         2    2741    1.00     2.0     4.0     3.50
# rshpsts            1         5    1233    0.45     1.0     6.0     1.21
# marsts             1         6    1411    0.51     1.0     6.0     5.30
#
#           MEDIAN  CORR_TARGET  SHARE_MOST_FREQ
# prtvtcit     7.0         0.01             0.39
# prtcldit     7.0        -0.01             0.36
# prtdgcl      2.0        -0.00             0.71
# rlgblge      2.0         0.02             0.76
# rlgdnme      1.0        -0.02             0.98
# ctzshipd     NaN          NaN             0.28
# cntbrthd     NaN          NaN             0.24
# livecnta  2002.0         0.11             0.07
# fbrncntc     NaN          NaN             0.22
# mbrncntc     NaN          NaN             0.22
# nbthcld      2.0        -0.06             0.48
# fcldbrn   1988.0         0.24             0.03
# ycldbyr   1990.0         0.21             0.03
# ngchld       0.0        -0.12             0.50
# ygcdbyr   2004.0         0.17             0.06
# ggchld       2.0        -0.02             0.84
# gndr3        2.0        -0.01             0.59
# gndr4        1.0         0.06             0.55
# gndr5        1.0        -0.09             0.51
# gndr6        1.0        -0.07             0.54
# gndr7        1.0         0.00             0.67
# gndr8        2.0        -1.00             0.75
# yrbrn3    1991.0         0.06             0.03
# yrbrn4    2000.0         0.06             0.06
# yrbrn5    2003.0         0.06             0.08
# yrbrn6    2005.5        -0.14             0.08
# yrbrn7    2001.0         0.00             0.17
# yrbrn8    2007.5         0.20             0.25
# rshipa3      2.0        -0.07             0.59
# rshipa4      2.0        -0.03             0.56
# rshipa5      4.0        -0.05             0.45
# rshipa6      4.0         0.26             0.50
# rshipa7      4.0         0.25             0.58
# rshipa8      4.0         0.33             0.75
# rshpsts      1.0         0.01             0.90
# marsts       6.0         0.14             0.65

# %%
df.drop(columns=too_many_nan_cols, inplace=True)

# %%
df_summary = get_summary_table(df, target_col="happy")
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN     MAX    MEAN  MEDIAN  \
# nwspol             1       295      91    0.03  0.0  1233.0  173.90    60.0
# netusoft           1         5       5    0.00  1.0     5.0    3.63     5.0
# netustm            1        60    1064    0.39  0.0   900.0  165.04   120.0
# ppltrst            1        11       9    0.00  0.0    10.0    4.79     5.0
# pplfair            1        11      25    0.01  0.0    10.0    4.83     5.0
# ...              ...       ...     ...     ...  ...     ...     ...     ...
# uempla             1         2       0    0.00  0.0     1.0    0.08     0.0
# uempli             1         2       0    0.00  0.0     1.0    0.03     0.0
# dsbld              1         2       0    0.00  0.0     1.0    0.01     0.0
# rtrd               1         2       0    0.00  0.0     1.0    0.26     0.0
# hswrk              1         2       0    0.00  0.0     1.0    0.10     0.0
#
#           CORR_TARGET  SHARE_MOST_FREQ
# nwspol           0.04             0.22
# netusoft         0.26             0.51
# netustm          0.01             0.17
# ppltrst          0.19             0.18
# pplfair          0.20             0.20
# ...               ...              ...
# uempla          -0.10             0.92
# uempli          -0.02             0.97
# dsbld           -0.02             0.99
# rtrd            -0.16             0.74
# hswrk           -0.00             0.90
#
# [136 rows x 10 columns]

# %% [markdown]
# ### 1.5 - Drop variables where less than 2% of the observations have a value different from the most frequent one
# There are some columns attaining a single value for the almost totality of the observations. While they might be useful to diagnose specific subsets of the population, they would hardly help us constructing our first models.

# %%
summary_filt = df_summary[df_summary["SHARE_MOST_FREQ"] > 0.97]
summary_filt
# Out:
#          IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN  MAX  MEAN  MEDIAN  \
# wrkprty           1         2      16    0.01  1.0  2.0  1.99     2.0
# dscrrce           1         2       0    0.00  0.0  1.0  0.01     0.0
# dscrntn           1         2       0    0.00  0.0  1.0  0.02     0.0
# dscrrlg           1         2       0    0.00  0.0  1.0  0.01     0.0
# dscrlng           1         2       0    0.00  0.0  1.0  0.00     0.0
# dscretn           1         2       0    0.00  0.0  1.0  0.01     0.0
# dscrage           1         2       0    0.00  0.0  1.0  0.00     0.0
# dscrgnd           1         2       0    0.00  0.0  1.0  0.00     0.0
# dscrsex           1         2       0    0.00  0.0  1.0  0.00     0.0
# dscrdsb           1         2       0    0.00  0.0  1.0  0.00     0.0
# dscroth           1         2       0    0.00  0.0  1.0  0.01     0.0
# dscrdk            1         2       0    0.00  0.0  1.0  0.00     0.0
# dscrref           1         2       0    0.00  0.0  1.0  0.00     0.0
# dsbld             1         2       0    0.00  0.0  1.0  0.01     0.0
#
#          CORR_TARGET  SHARE_MOST_FREQ
# wrkprty        -0.02             0.99
# dscrrce         0.00             0.99
# dscrntn        -0.04             0.98
# dscrrlg        -0.05             0.99
# dscrlng        -0.01             1.00
# dscretn        -0.05             0.99
# dscrage        -0.05             1.00
# dscrgnd        -0.02             1.00
# dscrsex         0.02             1.00
# dscrdsb        -0.03             1.00
# dscroth         0.01             0.99
# dscrdk         -0.07             1.00
# dscrref         0.01             1.00
# dsbld          -0.02             0.99

# %% [markdown]
# We drop these columns

# %%
df.drop(columns=summary_filt.index, inplace=True)

# %% [markdown]
# ### 1.6 - Drop variables with little to no correlation with target variable
# We proceed to drop all the variables having an absolute correlation less than
# or equal to 2% with the target variable.
#
# We make an exception for "gndr", representing gender, which will be used anyway as a control variable.

# %%
df_summary = get_summary_table(df, target_col="happy", descr_df=df_descr)

summary_filt = df_summary[df_summary["CORR_TARGET"].abs() <= 0.02]
low_corr_cols = summary_filt.index
summary_filt
# Out:
#          IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN    MAX    MEAN  MEDIAN  \
# admdw             1         3       0    0.00  1.0    3.0    1.99     2.0
# admge             1         2       0    0.00  1.0    2.0    1.49     1.0
# bctprd            1         2      20    0.01  1.0    2.0    1.93     2.0
# blgetmg           1         2      42    0.02  1.0    2.0    1.96     2.0
# brncntr           1         2       4    0.00  1.0    2.0    1.10     1.0
# crmvct            1         2      23    0.01  1.0    2.0    1.86     2.0
# ctzcntr           1         2      11    0.00  1.0    2.0    1.06     1.0
# evpdemp           1         2      18    0.01  1.0    2.0    1.32     1.0
# facntr            1         2       8    0.00  1.0    2.0    1.10     1.0
# gndr              1         2       0    0.00  1.0    2.0    1.53     2.0
# hswrk             1         2       0    0.00  0.0    1.0    0.10     0.0
# iagmr             1        23      81    0.03  0.0  111.0   20.31    25.0
# lrscale           1        11     744    0.27  0.0   10.0    5.26     5.0
# mocntr            1         2       9    0.00  1.0    2.0    1.10     1.0
# netustm           1        60    1064    0.39  0.0  900.0  165.04   120.0
# rlgatnd           1         7      40    0.01  1.0    7.0    4.86     5.0
# rlgblg            1         2      41    0.01  1.0    2.0    1.21     1.0
# rlgdgr            1        11      34    0.01  0.0   10.0    5.59     6.0
# rlgdnm            1         7     615    0.22  1.0    8.0    1.31     1.0
# rshipa2           1         6     509    0.19  1.0    6.0    1.66     1.0
# tochld            1        33     198    0.07  0.0   70.0   43.12    45.0
# tolvpnt           1        37     318    0.12  0.0   85.0   24.17    30.0
# towkht            1        34     380    0.14  0.0  111.0   53.91    60.0
# tygmr             1        25     181    0.07  0.0  111.0   20.54    20.0
# uempli            1         2       0    0.00  0.0    1.0    0.03     0.0
#
#          CORR_TARGET  SHARE_MOST_FREQ  \
# admdw           0.00             0.34
# admge          -0.00             0.51
# bctprd          0.00             0.93
# blgetmg        -0.00             0.96
# brncntr         0.00             0.90
# crmvct          0.00             0.86
# ctzcntr        -0.02             0.94
# evpdemp        -0.02             0.68
# facntr          0.01             0.90
# gndr           -0.01             0.53
# hswrk          -0.00             0.90
# iagmr          -0.00             0.31
# lrscale        -0.01             0.24
# mocntr          0.02             0.90
# netustm         0.01             0.17
# rlgatnd         0.02             0.23
# rlgblg          0.01             0.79
# rlgdgr          0.01             0.16
# rlgdnm         -0.01             0.92
# rshipa2        -0.01             0.67
# tochld          0.02             0.29
# tolvpnt         0.02             0.28
# towkht         -0.01             0.27
# tygmr          -0.00             0.32
# uempli         -0.02             0.97
#
#                                                      LABEL        TYPE
# admdw      Administration of how democracy works questions    discrete
# admge    Administration of split ballot, ask about fema...    discrete
# bctprd           Boycotted certain products last 12 months    discrete
# blgetmg         Belong to minority ethnic group in country    discrete
# brncntr                                    Born in country    discrete
# crmvct   Respondent or household member victim of burgl...    discrete
# ctzcntr                                 Citizen of country    discrete
# evpdemp  Paid employment or apprenticeship at least 3 m...    discrete
# facntr                              Father born in country    discrete
# gndr                                                Gender    discrete
# hswrk    Doing last 7 days: housework, looking after ch...    discrete
# iagmr                 Get married, ideal age. SPLIT BALLOT  continuous
# lrscale                      Placement on left right scale    discrete
# mocntr                              Mother born in country    discrete
# netustm  Internet use, how much time on typical day, in...  continuous
# rlgatnd  How often attend religious services apart from...    discrete
# rlgblg    Belonging to particular religion or denomination    discrete
# rlgdgr                               How religious are you    discrete
# rlgdnm    Religion or denomination belonging to at present    discrete
# rshipa2  Second person in household: relationship to re...    discrete
# tochld   Consider having more children, age too old. SP...  continuous
# tolvpnt  Still be living with parents, age too old. SPL...  continuous
# towkht   Be working 20 hours or more per week, age too ...  continuous
# tygmr             Get married, age too young. SPLIT BALLOT  continuous
# uempli   Doing last 7 days: unemployed, not actively lo...    discrete

# %%
df.drop(columns=low_corr_cols.difference(["gndr"]), inplace=True) ## not dropping the gndr column from the low_corr_cols

# %%
df_summary = get_summary_table(df, target_col="happy", descr_df=df_descr)
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL     MIN     MAX     MEAN  \
# acldnmr            1         5      38    0.01     1.0     5.0     3.42
# actrolga           1         5      67    0.02     1.0     5.0     1.91
# advcyc             1         5     134    0.05     1.0     5.0     2.82
# aesfdrk            1         4      50    0.02     1.0     4.0     2.22
# aftjbyc            1         5      88    0.03     1.0     5.0     3.39
# ...              ...       ...     ...     ...     ...     ...      ...
# vote               1         3      61    0.02     1.0     3.0     1.34
# vteurmmb           1         6     358    0.13     1.0    65.0     6.96
# wrkorg             1         2      21    0.01     1.0     2.0     1.93
# yrbrn              1        76      21    0.01  1928.0  2003.0  1967.68
# yrbrn2             1        88     570    0.21  1928.0  2018.0  1963.43
#
#           MEDIAN  CORR_TARGET  SHARE_MOST_FREQ  \
# acldnmr      4.0         0.16             0.44
# actrolga     2.0         0.12             0.39
# advcyc       3.0         0.12             0.43
# aesfdrk      2.0        -0.16             0.56
# aftjbyc      3.0         0.10             0.38
# ...          ...          ...              ...
# vote         1.0        -0.04             0.74
# vteurmmb     1.0        -0.14             0.70
# wrkorg       2.0        -0.08             0.93
# yrbrn     1967.0         0.21             0.02
# yrbrn2    1963.0         0.09             0.04
#
#                                                       LABEL        TYPE
# acldnmr   Approve if person have child with partner not ...    discrete
# actrolga        Able to take active role in political group    discrete
# advcyc    Approve if person gets divorced while children...    discrete
# aesfdrk   Feeling of safety of walking alone in local ar...    discrete
# aftjbyc   Approve if person has full- time job while chi...    discrete
# ...                                                     ...         ...
# vote                           Voted last national election    discrete
# vteurmmb  Would vote for [country] to remain member of E...    discrete
# wrkorg    Worked in another organisation or association ...    discrete
# yrbrn                                         Year of birth  continuous
# yrbrn2          Year of birth of second person in household  continuous
#
# [98 rows x 12 columns]

# %%
summary_filt1 = df_summary[df_summary["CORR_TARGET"].abs() <= 0.05]
low_corr_cols = summary_filt1.index
summary_filt1
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN     MAX    MEAN  MEDIAN  \
# ageadlt            1        33     105    0.04  0.0    80.0   19.65    20.0
# agemage            1        36      77    0.03  0.0    75.0   49.15    50.0
# ageoage            1        37      58    0.02  0.0    99.0   67.35    70.0
# bthcld             1         2      25    0.01  1.0     2.0    1.39     1.0
# contplt            1         2      21    0.01  1.0     2.0    1.90     2.0
# domicil            1         5       9    0.00  1.0     5.0    3.20     3.0
# dscrnap            1         2       0    0.00  0.0     1.0    0.96     1.0
# evmar              1         2      20    0.01  1.0     2.0    1.37     1.0
# gincdif            1         5      43    0.02  1.0     5.0    1.85     2.0
# gndr               1         2       0    0.00  1.0     2.0    1.53     2.0
# gndr2              1         2     503    0.18  1.0     2.0    1.41     1.0
# iaglptn            1        32     118    0.04  0.0   111.0   21.75    25.0
# iagpnt             1        28      84    0.03  0.0    50.0   22.23    28.0
# iagrtr             1        34     142    0.05  0.0   222.0   54.30    60.0
# lvgptnea           1         2     175    0.06  1.0     2.0    1.81     2.0
# nwspol             1       295      91    0.03  0.0  1233.0  173.90    60.0
# pbldmn             1         2      24    0.01  1.0     2.0    1.92     2.0
# pray               1         7     104    0.04  1.0     7.0    4.08     4.0
# pstplonl           1         2      33    0.01  1.0     2.0    1.86     2.0
# sgnptit            1         2      20    0.01  1.0     2.0    1.86     2.0
# tygpnt             1        30     175    0.06  0.0    51.0   19.80    20.0
# tygrtr             1        42     290    0.11  0.0   222.0   50.42    50.0
# vote               1         3      61    0.02  1.0     3.0    1.34     1.0
#
#           CORR_TARGET  SHARE_MOST_FREQ  \
# ageadlt          0.03             0.19
# agemage          0.05             0.34
# ageoage          0.05             0.32
# bthcld           0.04             0.61
# contplt         -0.03             0.90
# domicil          0.04             0.43
# dscrnap          0.05             0.96
# evmar            0.03             0.63
# gincdif          0.04             0.53
# gndr            -0.01             0.53
# gndr2           -0.05             0.59
# iaglptn         -0.05             0.36
# iagpnt           0.03             0.28
# iagrtr          -0.03             0.32
# lvgptnea         0.03             0.81
# nwspol           0.04             0.22
# pbldmn          -0.05             0.92
# pray             0.04             0.22
# pstplonl        -0.05             0.86
# sgnptit         -0.05             0.86
# tygpnt           0.05             0.29
# tygrtr          -0.05             0.30
# vote            -0.04             0.74
#
#                                                       LABEL        TYPE
# ageadlt                     Age become adults. SPLIT BALLOT  continuous
# agemage                  Age reach middle age. SPLIT BALLOT  continuous
# ageoage                     Age reach old age. SPLIT BALLOT  continuous
# bthcld                Ever given birth to/ fathered a child    discrete
# contplt   Contacted politician or government official la...    discrete
# domicil                  Domicile, respondent's description    discrete
# dscrnap   Discrimination of respondent's group: not appl...    discrete
# evmar                              Are or ever been married    discrete
# gincdif   Government should reduce differences in income...    discrete
# gndr                                                 Gender    discrete
# gndr2                  Gender of second person in household    discrete
# iaglptn   Start living with partner not married to, idea...  continuous
# iagpnt       Become mother/ father, ideal age. SPLIT BALLOT  continuous
# iagrtr          Retire permanently, ideal age. SPLIT BALLOT  continuous
# lvgptnea   Ever lived with a partner, without being married    discrete
# nwspol    News about politics and current affairs, watch...  continuous
# pbldmn    Taken part in lawful public demonstration last...    discrete
# pray        How often pray apart from at religious services    discrete
# pstplonl  Posted or shared anything about politics onlin...    discrete
# sgnptit                      Signed petition last 12 months    discrete
# tygpnt    Become mother/ father, age too young. SPLIT BA...  continuous
# tygrtr      Retire permanently, age too young. SPLIT BALLOT  continuous
# vote                           Voted last national election    discrete

# %%
summary_filt1.sort_values("CORR_TARGET", axis=0, ascending=True, inplace=False)
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN     MAX    MEAN  MEDIAN  \
# iaglptn            1        32     118    0.04  0.0   111.0   21.75    25.0
# sgnptit            1         2      20    0.01  1.0     2.0    1.86     2.0
# pstplonl           1         2      33    0.01  1.0     2.0    1.86     2.0
# pbldmn             1         2      24    0.01  1.0     2.0    1.92     2.0
# tygrtr             1        42     290    0.11  0.0   222.0   50.42    50.0
# gndr2              1         2     503    0.18  1.0     2.0    1.41     1.0
# vote               1         3      61    0.02  1.0     3.0    1.34     1.0
# contplt            1         2      21    0.01  1.0     2.0    1.90     2.0
# iagrtr             1        34     142    0.05  0.0   222.0   54.30    60.0
# gndr               1         2       0    0.00  1.0     2.0    1.53     2.0
# evmar              1         2      20    0.01  1.0     2.0    1.37     1.0
# iagpnt             1        28      84    0.03  0.0    50.0   22.23    28.0
# lvgptnea           1         2     175    0.06  1.0     2.0    1.81     2.0
# ageadlt            1        33     105    0.04  0.0    80.0   19.65    20.0
# gincdif            1         5      43    0.02  1.0     5.0    1.85     2.0
# domicil            1         5       9    0.00  1.0     5.0    3.20     3.0
# nwspol             1       295      91    0.03  0.0  1233.0  173.90    60.0
# bthcld             1         2      25    0.01  1.0     2.0    1.39     1.0
# pray               1         7     104    0.04  1.0     7.0    4.08     4.0
# ageoage            1        37      58    0.02  0.0    99.0   67.35    70.0
# agemage            1        36      77    0.03  0.0    75.0   49.15    50.0
# tygpnt             1        30     175    0.06  0.0    51.0   19.80    20.0
# dscrnap            1         2       0    0.00  0.0     1.0    0.96     1.0
#
#           CORR_TARGET  SHARE_MOST_FREQ  \
# iaglptn         -0.05             0.36
# sgnptit         -0.05             0.86
# pstplonl        -0.05             0.86
# pbldmn          -0.05             0.92
# tygrtr          -0.05             0.30
# gndr2           -0.05             0.59
# vote            -0.04             0.74
# contplt         -0.03             0.90
# iagrtr          -0.03             0.32
# gndr            -0.01             0.53
# evmar            0.03             0.63
# iagpnt           0.03             0.28
# lvgptnea         0.03             0.81
# ageadlt          0.03             0.19
# gincdif          0.04             0.53
# domicil          0.04             0.43
# nwspol           0.04             0.22
# bthcld           0.04             0.61
# pray             0.04             0.22
# ageoage          0.05             0.32
# agemage          0.05             0.34
# tygpnt           0.05             0.29
# dscrnap          0.05             0.96
#
#                                                       LABEL        TYPE
# iaglptn   Start living with partner not married to, idea...  continuous
# sgnptit                      Signed petition last 12 months    discrete
# pstplonl  Posted or shared anything about politics onlin...    discrete
# pbldmn    Taken part in lawful public demonstration last...    discrete
# tygrtr      Retire permanently, age too young. SPLIT BALLOT  continuous
# gndr2                  Gender of second person in household    discrete
# vote                           Voted last national election    discrete
# contplt   Contacted politician or government official la...    discrete
# iagrtr          Retire permanently, ideal age. SPLIT BALLOT  continuous
# gndr                                                 Gender    discrete
# evmar                              Are or ever been married    discrete
# iagpnt       Become mother/ father, ideal age. SPLIT BALLOT  continuous
# lvgptnea   Ever lived with a partner, without being married    discrete
# ageadlt                     Age become adults. SPLIT BALLOT  continuous
# gincdif   Government should reduce differences in income...    discrete
# domicil                  Domicile, respondent's description    discrete
# nwspol    News about politics and current affairs, watch...  continuous
# bthcld                Ever given birth to/ fathered a child    discrete
# pray        How often pray apart from at religious services    discrete
# ageoage                     Age reach old age. SPLIT BALLOT  continuous
# agemage                  Age reach middle age. SPLIT BALLOT  continuous
# tygpnt    Become mother/ father, age too young. SPLIT BA...  continuous
# dscrnap   Discrimination of respondent's group: not appl...    discrete

# %% [markdown]
# ### |3|% = {"ageadlt","contplt","iagpnt","iagrtr","lvgptnea",""}, |4|% = {"nwspol","pbldmn","vote","gincdif"}, |5|% = {"agemage","ageoage","sgnptit","dscrnap","iaglptn","pstplonl","pbldmn","tygrtr", "tygpnt"} some variable to consider = {"domicil", "bthcld", "evrmar", "gndr", "gndr2"}

# %%
df.drop(columns=low_corr_cols.difference(["domicil", "bthcld", "evrmar", "gndr", "gndr2"]), inplace=True) ## not dropping the gndr column from the low_corr_cols

# %% [markdown]
# #### Removing the columns which is a ballot to know the opinion on approval or disapproval of a thirds person life.
# these columns have the word "BALLOT" in their Label column in the description table

# %%
df_summary = get_summary_table(df, target_col="happy", descr_df=df_descr)
df_summary[df_summary['LABEL'].str.contains("BALLOT")]
# Out:
#          IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL  MIN    MAX   MEAN  MEDIAN  \
# acldnmr           1         5      38    0.01  1.0    5.0   3.42     4.0
# advcyc            1         5     134    0.05  1.0    5.0   2.82     3.0
# aftjbyc           1         5      88    0.03  1.0    5.0   3.39     3.0
# alvgptn           1         5      40    0.01  1.0    5.0   3.47     4.0
# anvcld            1         5      66    0.02  1.0    5.0   3.01     3.0
# tygledu           1        27     250    0.09  0.0   60.0  15.33    17.0
# tyglvp            1        25     242    0.09  0.0  111.0  24.57    20.0
#
#          CORR_TARGET  SHARE_MOST_FREQ  \
# acldnmr         0.16             0.44
# advcyc          0.12             0.43
# aftjbyc         0.10             0.38
# alvgptn         0.17             0.44
# anvcld          0.14             0.47
# tygledu         0.06             0.26
# tyglvp         -0.12             0.29
#
#                                                      LABEL        TYPE
# acldnmr  Approve if person have child with partner not ...    discrete
# advcyc   Approve if person gets divorced while children...    discrete
# aftjbyc  Approve if person has full- time job while chi...    discrete
# alvgptn  Approve if person lives with partner not marri...    discrete
# anvcld   Approve if person chooses never to have childr...    discrete
# tygledu  Leave full-time education, age too young. SPLI...  continuous
# tyglvp   Start living with partner not married to, age ...  continuous

# %%
ballot_split_col = df_summary[df_summary['LABEL'].str.contains("BALLOT")].index
ballot_split_col
# Out:
# Index(['acldnmr', 'advcyc', 'aftjbyc', 'alvgptn', 'anvcld', 'tygledu',
#        'tyglvp'],
#       dtype='object')

# %% [markdown]
# #### not relavant according to me = {"acldnmr", "advcyc", "aftjbyc", "anvcld", "tygledu", "tyglvp"}
#
# #### relavant according to me = {"alvgptn"}`

# %%
df.drop(columns=ballot_split_col.difference(["alvgptn"]), inplace=True) ## not dropping the gndr column from the low_corr_cols

# %%
corr_mat = df.corr(method="pearson")

# %%
df["happy"]
# Out:
# 0       8.0
# 1       5.0
# 2       8.0
# 3       8.0
# 4       7.0
#        ...
# 2740    9.0
# 2741    7.0
# 2742    8.0
# 2743    9.0
# 2744    5.0
# Name: happy, Length: 2745, dtype: float64

# %%
mat = df.copy()
mat
# Out:
#       netusoft  ppltrst  pplfair  pplhlp  polintr  psppsgva  actrolga  \
# 0          4.0      2.0      3.0     5.0      3.0       1.0       2.0
# 1          5.0      5.0      5.0     6.0      3.0       4.0       1.0
# 2          5.0      4.0      4.0     5.0      2.0       2.0       2.0
# 3          5.0      6.0      6.0     5.0      2.0       2.0       2.0
# 4          5.0      2.0      3.0     2.0      2.0       3.0       1.0
# ...        ...      ...      ...     ...      ...       ...       ...
# 2740       3.0      2.0      7.0     7.0      4.0       2.0       1.0
# 2741       1.0      4.0      5.0     5.0      4.0       1.0       1.0
# 2742       5.0      5.0      5.0     4.0      2.0       3.0       3.0
# 2743       5.0      2.0      5.0     5.0      3.0       2.0       2.0
# 2744       5.0      8.0      8.0     0.0      4.0       1.0       1.0
#
#       psppipla  cptppola  trstprl  ...  chldhhe  domicil  edulvlb  eisced  \
# 0          1.0       3.0      5.0  ...      NaN      4.0    313.0     4.0
# 1          3.0       1.0      NaN  ...      2.0      4.0    213.0     2.0
# 2          2.0       2.0      6.0  ...      2.0      3.0    620.0     6.0
# 3          2.0       3.0      7.0  ...      2.0      4.0    620.0     6.0
# 4          2.0       2.0      0.0  ...      NaN      4.0    213.0     2.0
# ...        ...       ...      ...  ...      ...      ...      ...     ...
# 2740       2.0       2.0      0.0  ...      2.0      3.0    113.0     1.0
# 2741       1.0       1.0      4.0  ...      1.0      4.0    213.0     2.0
# 2742       3.0       3.0      4.0  ...      NaN      3.0    321.0     3.0
# 2743       3.0       3.0      6.0  ...      2.0      3.0    213.0     2.0
# 2744       1.0       1.0      5.0  ...      2.0      3.0    213.0     2.0
#
#       edlveit  eduyrs  pdwrk  edctn  uempla  rtrd
# 0         9.0    13.0      0      0       0     0
# 1         4.0    10.0      0      0       0     0
# 2        12.0    15.0      1      0       0     0
# 3        12.0    20.0      1      0       0     0
# 4         4.0     8.0      1      0       0     0
# ...       ...     ...    ...    ...     ...   ...
# 2740      2.0     5.0      0      0       0     1
# 2741      4.0    13.0      0      0       0     1
# 2742      6.0    13.0      0      0       0     1
# 2743      4.0    12.0      0      1       0     0
# 2744      4.0    12.0      0      1       0     0
#
# [2745 rows x 73 columns]

# %%
#mat.drop(columns= ["happy"],axis = 1,inplace = True)
mat.drop(columns= "happy", inplace = True)

# %%
#mat[[mat.abs() == 1]] = 0
mat.iloc[0,1]
# Out:
# 2.0

# %%
mat[mat.abs() > 0.85]
# Out:
#           netusoft  ppltrst  pplfair  pplhlp  polintr  psppsgva  actrolga  \
# netusoft       NaN      NaN      NaN     NaN      NaN       NaN       NaN
# ppltrst        NaN      NaN      NaN     NaN      NaN       NaN       NaN
# pplfair        NaN      NaN      NaN     NaN      NaN       NaN       NaN
# pplhlp         NaN      NaN      NaN     NaN      NaN       NaN       NaN
# polintr        NaN      NaN      NaN     NaN      NaN       NaN       NaN
# ...            ...      ...      ...     ...      ...       ...       ...
# eduyrs         NaN      NaN      NaN     NaN      NaN       NaN       NaN
# pdwrk          NaN      NaN      NaN     NaN      NaN       NaN       NaN
# edctn          NaN      NaN      NaN     NaN      NaN       NaN       NaN
# uempla         NaN      NaN      NaN     NaN      NaN       NaN       NaN
# rtrd           NaN      NaN      NaN     NaN      NaN       NaN       NaN
#
#           psppipla  cptppola  trstprl  ...  chldhhe  domicil  edulvlb  eisced  \
# netusoft       NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# ppltrst        NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# pplfair        NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# pplhlp         NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# polintr        NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# ...            ...       ...      ...  ...      ...      ...      ...     ...
# eduyrs         NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# pdwrk          NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# edctn          NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# uempla         NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
# rtrd           NaN       NaN      NaN  ...      NaN      NaN      NaN     NaN
#
#            edlveit  eduyrs  pdwrk  edctn  uempla  rtrd
# netusoft       NaN     NaN    NaN    NaN     NaN   NaN
# ppltrst        NaN     NaN    NaN    NaN     NaN   NaN
# pplfair        NaN     NaN    NaN    NaN     NaN   NaN
# pplhlp         NaN     NaN    NaN    NaN     NaN   NaN
# polintr        NaN     NaN    NaN    NaN     NaN   NaN
# ...            ...     ...    ...    ...     ...   ...
# eduyrs    0.860602     NaN    NaN    NaN     NaN   NaN
# pdwrk          NaN     NaN    NaN    NaN     NaN   NaN
# edctn          NaN     NaN    NaN    NaN     NaN   NaN
# uempla         NaN     NaN    NaN    NaN     NaN   NaN
# rtrd           NaN     NaN    NaN    NaN     NaN   NaN
#
# [71 rows x 71 columns]

# %%
def remove_collinear_features(x, threshold):
    '''
    Objective:
        Remove collinear features in a dataframe with a correlation coefficient
        greater than the threshold. Removing collinear features can help a model 
        to generalize and improves the interpretability of the model.

    Inputs: 
        x: features dataframe
        threshold: features with correlations greater than this value are removed

    Output: 
        dataframe that contains only the non-highly-collinear features
    '''

    # Calculate the correlation matrix
    corr_matrix = x.corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    # Iterate through the correlation matrix and compare correlations
    for i in iters:
        for j in range(i+1):
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            # If correlation exceeds the threshold
            if val >= threshold:
                # Print the correlated features and the correlation value
                print(col.values[0], "|", row.values[0], "|", round(val[0][0], 2))
                drop_cols.append(col.values[0])

    # Drop one of each pair of correlated columns
    drops = set(drop_cols)
    #x = x.drop(columns=drops)

    return drops

# %%
multi_col_clmns = remove_collinear_features(mat,0.85)
multi_col_clmns
# Out:
# trstprt | trstplt | 0.89
# lvptnyr | pdempyr | 0.9
# maryr | pdempyr | 0.88
# maryr | lvptnyr | 0.99
# agea | pdempyr | 0.93
# agea | lvptnyr | 0.95
# agea | maryr | 0.94
# yrbrn | pdempyr | 0.93
# yrbrn | lvptnyr | 0.95
# yrbrn | maryr | 0.94
# yrbrn | agea | 1.0
# eisced | edulvlb | 0.96
# edlveit | edulvlb | 0.96
# edlveit | eisced | 0.99
# eduyrs | edlveit | 0.86
# ['edlveit', 'agea', 'yrbrn', 'maryr', 'eduyrs', 'lvptnyr', 'trstprt', 'eisced']

# %%
df_summary = get_summary_table(df, target_col="happy", descr_df=df_descr)
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL     MIN     MAX     MEAN  \
# actrolga           1         5      67    0.02     1.0     5.0     1.91
# aesfdrk            1         4      50    0.02     1.0     4.0     2.22
# agea               1        75      21    0.01    16.0    90.0    51.28
# alvgptn            1         5      40    0.01     1.0     5.0     3.47
# atchctr            1        11      15    0.01     0.0    10.0     8.06
# ...              ...       ...     ...     ...     ...     ...      ...
# uempla             1         2       0    0.00     0.0     1.0     0.08
# vteurmmb           1         6     358    0.13     1.0    65.0     6.96
# wrkorg             1         2      21    0.01     1.0     2.0     1.93
# yrbrn              1        76      21    0.01  1928.0  2003.0  1967.68
# yrbrn2             1        88     570    0.21  1928.0  2018.0  1963.43
#
#           MEDIAN  CORR_TARGET  SHARE_MOST_FREQ  \
# actrolga     2.0         0.12             0.39
# aesfdrk      2.0        -0.16             0.56
# agea        52.0        -0.21             0.02
# alvgptn      4.0         0.17             0.44
# atchctr      8.0         0.22             0.29
# ...          ...          ...              ...
# uempla       0.0        -0.10             0.92
# vteurmmb     1.0        -0.14             0.70
# wrkorg       2.0        -0.08             0.93
# yrbrn     1967.0         0.21             0.02
# yrbrn2    1963.0         0.09             0.04
#
#                                                       LABEL        TYPE
# actrolga        Able to take active role in political group    discrete
# aesfdrk   Feeling of safety of walking alone in local ar...    discrete
# agea                          Age of respondent, calculated  continuous
# alvgptn   Approve if person lives with partner not marri...    discrete
# atchctr               How emotionally attached to [country]    discrete
# ...                                                     ...         ...
# uempla    Doing last 7 days: unemployed, actively lookin...    discrete
# vteurmmb  Would vote for [country] to remain member of E...    discrete
# wrkorg    Worked in another organisation or association ...    discrete
# yrbrn                                         Year of birth  continuous
# yrbrn2          Year of birth of second person in household  continuous
#
# [73 rows x 12 columns]

# %%
for i in ['edlveit', 'agea', 'yrbrn', 'maryr', 'eduyrs', 'lvptnyr', 'trstprt', 'eisced']:
    df1 = pd.DataFrame(df_summary[df_summary.index.values == i])
    print(df1["LABEL"])
# Out:
# edlveit    Highest level of education, Italy
# Name: LABEL, dtype: object
# agea    Age of respondent, calculated
# Name: LABEL, dtype: object
# yrbrn    Year of birth
# Name: LABEL, dtype: object
# maryr    Year first married
# Name: LABEL, dtype: object
# eduyrs    Years of full-time education completed
# Name: LABEL, dtype: object
# lvptnyr    Year first lived with spouse or partner for 3 ...
# Name: LABEL, dtype: object
# trstprt    Trust in political parties
# Name: LABEL, dtype: object
# eisced    Highest level of education, ES - ISCED
# Name: LABEL, dtype: object

# %%
multi_col_clmns = ['edlveit', 'agea', 'eduyrs', 'lvptnyr', 'trstprt', 'eisced','pdempyr']
multi_col_clmns
# Out:
# ['edlveit', 'agea', 'eduyrs', 'lvptnyr', 'trstprt', 'eisced', 'pdempyr']

# %% [markdown]
# By manually analyzing these variables, we came down to the above list variables which can be removed from the df

# %%
df.drop(columns=multi_col_clmns, inplace=True) 
df
# Out:
#       netusoft  ppltrst  pplfair  pplhlp  polintr  psppsgva  actrolga  \
# 0          4.0      2.0      3.0     5.0      3.0       1.0       2.0
# 1          5.0      5.0      5.0     6.0      3.0       4.0       1.0
# 2          5.0      4.0      4.0     5.0      2.0       2.0       2.0
# 3          5.0      6.0      6.0     5.0      2.0       2.0       2.0
# 4          5.0      2.0      3.0     2.0      2.0       3.0       1.0
# ...        ...      ...      ...     ...      ...       ...       ...
# 2740       3.0      2.0      7.0     7.0      4.0       2.0       1.0
# 2741       1.0      4.0      5.0     5.0      4.0       1.0       1.0
# 2742       5.0      5.0      5.0     4.0      2.0       3.0       3.0
# 2743       5.0      2.0      5.0     5.0      3.0       2.0       2.0
# 2744       5.0      8.0      8.0     0.0      4.0       1.0       1.0
#
#       psppipla  cptppola  trstprl  ...  yrbrn2  dvrcdeva  maritalb  chldhhe  \
# 0          1.0       3.0      5.0  ...  1981.0       2.0       1.0      NaN
# 1          3.0       1.0      NaN  ...  1966.0       2.0       6.0      2.0
# 2          2.0       2.0      6.0  ...  1959.0       2.0       6.0      2.0
# 3          2.0       3.0      7.0  ...  1954.0       2.0       6.0      2.0
# 4          2.0       2.0      0.0  ...  1980.0       2.0       1.0      NaN
# ...        ...       ...      ...  ...     ...       ...       ...      ...
# 2740       2.0       2.0      0.0  ...     NaN       2.0       5.0      2.0
# 2741       1.0       1.0      4.0  ...     NaN       2.0       1.0      1.0
# 2742       3.0       3.0      4.0  ...  1957.0       2.0       1.0      NaN
# 2743       3.0       3.0      6.0  ...  1965.0       2.0       6.0      2.0
# 2744       1.0       1.0      5.0  ...  1960.0       2.0       6.0      2.0
#
#       domicil  edulvlb  pdwrk  edctn  uempla  rtrd
# 0         4.0    313.0      0      0       0     0
# 1         4.0    213.0      0      0       0     0
# 2         3.0    620.0      1      0       0     0
# 3         4.0    620.0      1      0       0     0
# 4         4.0    213.0      1      0       0     0
# ...       ...      ...    ...    ...     ...   ...
# 2740      3.0    113.0      0      0       0     1
# 2741      4.0    213.0      0      0       0     1
# 2742      3.0    321.0      0      0       0     1
# 2743      3.0    213.0      0      1       0     0
# 2744      3.0    213.0      0      1       0     0
#
# [2745 rows x 66 columns]

# %%
df_summary = get_summary_table(df, target_col="happy", descr_df=df_descr)
df_summary
# Out:
#           IS_NUMERIC  N_UNIQUE  NA_ABS  NA_REL     MIN     MAX     MEAN  \
# actrolga           1         5      67    0.02     1.0     5.0     1.91
# aesfdrk            1         4      50    0.02     1.0     4.0     2.22
# alvgptn            1         5      40    0.01     1.0     5.0     3.47
# atchctr            1        11      15    0.01     0.0    10.0     8.06
# atcherp            1        11      55    0.02     0.0    10.0     5.66
# ...              ...       ...     ...     ...     ...     ...      ...
# uempla             1         2       0    0.00     0.0     1.0     0.08
# vteurmmb           1         6     358    0.13     1.0    65.0     6.96
# wrkorg             1         2      21    0.01     1.0     2.0     1.93
# yrbrn              1        76      21    0.01  1928.0  2003.0  1967.68
# yrbrn2             1        88     570    0.21  1928.0  2018.0  1963.43
#
#           MEDIAN  CORR_TARGET  SHARE_MOST_FREQ  \
# actrolga     2.0         0.12             0.39
# aesfdrk      2.0        -0.16             0.56
# alvgptn      4.0         0.17             0.44
# atchctr      8.0         0.22             0.29
# atcherp      6.0         0.27             0.19
# ...          ...          ...              ...
# uempla       0.0        -0.10             0.92
# vteurmmb     1.0        -0.14             0.70
# wrkorg       2.0        -0.08             0.93
# yrbrn     1967.0         0.21             0.02
# yrbrn2    1963.0         0.09             0.04
#
#                                                       LABEL        TYPE
# actrolga        Able to take active role in political group    discrete
# aesfdrk   Feeling of safety of walking alone in local ar...    discrete
# alvgptn   Approve if person lives with partner not marri...    discrete
# atchctr               How emotionally attached to [country]    discrete
# atcherp                  How emotionally attached to Europe    discrete
# ...                                                     ...         ...
# uempla    Doing last 7 days: unemployed, actively lookin...    discrete
# vteurmmb  Would vote for [country] to remain member of E...    discrete
# wrkorg    Worked in another organisation or association ...    discrete
# yrbrn                                         Year of birth  continuous
# yrbrn2          Year of birth of second person in household  continuous
#
# [66 rows x 12 columns]

# %%
df_summary.to_excel("manual_var_sel.xlsx")

# %%
df[["imbgeco", "imdfetn", "impcntr","imsmetn","imueclt","imwbcnt"]].corr(method = "pearson")
# Out:
#           imbgeco   imdfetn   impcntr   imsmetn   imueclt   imwbcnt
# imbgeco  1.000000 -0.624092 -0.600034 -0.593944  0.778487  0.738672
# imdfetn -0.624092  1.000000  0.824184  0.824261 -0.626388 -0.563450
# impcntr -0.600034  0.824184  1.000000  0.716150 -0.597612 -0.553877
# imsmetn -0.593944  0.824261  0.716150  1.000000 -0.579414 -0.525670
# imueclt  0.778487 -0.626388 -0.597612 -0.579414  1.000000  0.747096
# imwbcnt  0.738672 -0.563450 -0.553877 -0.525670  0.747096  1.000000
